# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt',index_col=0)

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 10)
#       UNIT       SCP STATION LINENAME DIVISION        DATE      TIME     DESC  \
# C/A
# A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00  REGULAR
# A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00  REGULAR
# A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00  REGULAR
# A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00  REGULAR
# A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00  REGULAR
#
#       ENTRIES  \
# C/A
# A002  6736067
# A002  6736087
# A002  6736105
# A002  6736180
# A002  6736349
#
#       EXITS
# C/A
# A002                                            2283184
# A002                                            2283188
# A002                                            2283229
# A002                                            2283314
# A002                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
# We can check and see what the columns look like with this code:
df.columns
# Out:
# Index(['UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
# Rename all the columns to lower case
df.columns=df.columns.str.lower()

# %%
# Now let's check and make sure that worked
df.columns
# Out:
# Index(['unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
df.set_index('linename')
# Out:
#           unit       scp        station division        date      time  \
# linename
# NQR456W   R051  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# NQR456W   R051  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# NQR456W   R051  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# NQR456W   R051  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# NQR456W   R051  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# ...        ...       ...            ...      ...         ...       ...
# R         R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  05:00:00
# R         R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  09:00:00
# R         R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  13:00:00
# R         R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  17:00:00
# R         R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  21:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
# ...           ...      ...
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384
# ...                                                     ...
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
#
# [197625 rows x 9 columns]

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df.reset_index()
# Out:
#           C/A  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries  \
# 0       00:00:00  REGULAR  6736067
# 1       04:00:00  REGULAR  6736087
# 2       08:00:00  REGULAR  6736105
# 3       12:00:00  REGULAR  6736180
# 4       16:00:00  REGULAR  6736349
# ...          ...      ...      ...
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 11 columns]

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
df['num_lines']
# Out:
# C/A
# A002    NaN
# A002    NaN
# A002    NaN
# A002    NaN
# A002    NaN
#          ..
# TRAM2   NaN
# TRAM2   NaN
# TRAM2   NaN
# TRAM2   NaN
# TRAM2   NaN
# Name: num_lines, Length: 197625, dtype: float64

# %% [markdown]
# Write a function to clean column names:

# %%
# Before we start cleaning, let's look at what we've got

df.columns
# Out:
# Index(['unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'num_lines'],
#       dtype='object')

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = col_name.strip()
    return cleaned

# %%
# Use the above function to clean the column names
df['num_lines']=(df['linename'].map(clean)).map(len)
df=df.drop(columns='num_line')

# %%
# Check to ensure the column names were cleaned
df.loc[:,['num_lines','linename']]
# Out:
#        num_lines linename
# C/A
# A002           7  NQR456W
# A002           7  NQR456W
# A002           7  NQR456W
# A002           7  NQR456W
# A002           7  NQR456W
# ...          ...      ...
# TRAM2          1        R
# TRAM2          1        R
# TRAM2          1        R
# TRAM2          1        R
# TRAM2          1        R
#
# [197625 rows x 2 columns]

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
df['date']
# Out:
# C/A
# A002     08/25/2018
# A002     08/25/2018
# A002     08/25/2018
# A002     08/25/2018
# A002     08/25/2018
#             ...
# TRAM2    08/31/2018
# TRAM2    08/31/2018
# TRAM2    08/31/2018
# TRAM2    08/31/2018
# TRAM2    08/31/2018
# Name: date, Length: 197625, dtype: object

# %%
# Convert the data type of the 'date' column to a date
df['date']=pd.to_datetime(df['date'],format='%m/%d/%Y')


# Add a new column 'day_of_week' that represents the day of the week 
df['day_of_week']=df['date'].dt.day_name()
df['day_of_week']
# Out:
# C/A
# A002     Saturday
# A002     Saturday
# A002     Saturday
# A002     Saturday
# A002     Saturday
#            ...
# TRAM2      Friday
# TRAM2      Friday
# TRAM2      Friday
# TRAM2      Friday
# TRAM2      Friday
# Name: day_of_week, Length: 197625, dtype: object

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum(numeric_only = True)
grouped.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped = grouped.reset_index()

# Print the first five rows of grouped
grouped.head(5)
# Out:
#   day_of_week        entries  \
# 0      Friday  1110224700078
# 1      Monday  1114237052454
# 2    Saturday  1115661545514
# 3      Sunday  1192306179082
# 4    Thursday  1122723988662
#
#    exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
#
#    num_lines
# 0      75573
# 1      76110
# 2      74725
# 3      75306
# 4      76607

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped['is_weekend'] = grouped['day_of_week'].map(weekend_map)

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').sum(numeric_only = True)
wkend[['entries', 'exits']].plot(kind='barh')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 3
#       1 # Group the data by weekend/weekday and plot the sum of the numeric columns
#       2 wkend = grouped.groupby('is_weekend').sum(numeric_only = True)
# ----> 3 wkend[['entries', 'exits']].plot(kind='barh')
#       4 plt.show()
#
# File c:\Users\Miry\Documents\data-science\.venv\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Miry\Documents\data-science\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Miry\Documents\data-science\.venv\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['exits'] not in index"

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
df = None
df.head(2)

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Summary
#
# You practiced your data cleanup skills using Pandas.
